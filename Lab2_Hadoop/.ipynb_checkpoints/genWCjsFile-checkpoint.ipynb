# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#inputRead = "coOccur_part-00000"
#inputRead = "twitter1day_part-00000"
inputRead = "CoOccurTwitter1day_part-00001"
#print(f.read())
tableData = pd.read_table(inputRead, sep = "\t")
tableData.columns = ['word','count']
print(tableData)
# Out:
#                                           word  count
# 0                                    1,billion      3
# 1                                100,perfectli      1
# 2                                   1013,great      7
# 3                    11\n\ndataleak,dataanalyt      1
# 4     11\n\ndataleak,dataanalytics\xe2\x80\xa6      1
# 5                                    11am,hall      1
# 6                                      11h,13h      1
# 7                                      13,dear      1
# 8                                      13h,15h      1
# 9                                   13th,april      1
# 10           15h,s//tco/xemirtiefu\xe2\x80\xa6      1
# 11                                1960doe,true      1
# 12                                  2014,elect      1
# 13                                2016,practic      1
# 14                         2016,wa\xe2\x80\xa6      1
# 15          2016\xe2\x80\xa6,s//tco/zogpfvhmd2      1
# 16                             2017,privacyint      3
# 17                                 2018,confer      1
# 18                                   2018,next      1
# 19                                  2018,trade      1
# 20                 20181139am,\n\n\xe2\x9e\xa1      3
# 21                                  2019,elect      1
# 22                         2019,ma\xe2\x80\xa6      1
# 23           201\xe2\x80\xa6,s//tco/pyfkacsq3z      1
# 24                               22,20181139am      3
# 25                     232a,during\xe2\x80\xa6      1
# 26                                  27,million      4
# 27                                    270,page      1
# 28                                     3,stand      6
# 29                                  307,\nhplc      1
# ...                                        ...    ...
# 1635                          wikileak,founder     47
# 1636                             wildli,confus      1
# 1637                           without,permiss      1
# 1638             without\n\nfacebook,analytica      1
# 1639         wor\xe2\x80\xa6,s//tco/qmqpwxxdep      1
# 1640                         work,\xe2\x80\x94      1
# 1641                                 work,mayb      1
# 1642                                 work,work      1
# 1643                    worker,see\xe2\x80\xa6      1
# 1644                                 world,app      1
# 1645                             world,privaci      1
# 1646                     y\xe2\x80\x99al,watch      1
# 1647           y\xe2\x80\xa6,s//tco/rj1k8xy2xr      1
# 1648                         yangheeleeskku,ha      5
# 1649                              ye,certainli      3
# 1650                                    year,A      1
# 1651                              year,special      1
# 1652                                  year,whi      3
# 1653                                  yera,ngo      2
# 1654                                 youd,like      1
# 1655                    youtub,fac\xe2\x80\xa6      1
# 1656                    zkhamashuridz,cambridg      1
# 1657           zuckerberg,facebook\xe2\x80\x99      1
# 1658                           zuckerberg,fire      1
# 1659                           zuckerberg,like      1
# 1660                                |,cambridg      2
# 1661                                    |,leak      3
# 1662                      |,scoopi\xe2\x80\xa6      1
# 1663                                   |,stole      2
# 1664           |\xe2\x80\xa6,s//tco/qvxzwu89so      1
#
# [1665 rows x 2 columns]

# %%
nrows = tableData.shape[0]
nrows
# Out:
# 1665

# %%
sortedData = tableData.sort_values('count',ascending= False)
sortedData
# Out:
#                                                   word  count
# 560                                 cambridg,analytica    126
# 905                                             ha,new     49
# 246                           analytica,scandal\ntwitt     49
# 1411                                    shortterm,pain     49
# 789                                       facebook,amp     49
# 1154                                         new,autom     49
# 1323                                rules\n1,shortterm     49
# 162                                      amp,analytica     49
# 1382                                 scandal\ntwitt,ha     49
# 315                                     autom,rules\n1     49
# 314                                          autom,\na     48
# 1212                                  orlando7770,amid     48
# 159                                      amid,facebook     48
# 503                                    brt,orlando7770     48
# 94                                   \na,n\xe2\x80\xa6     48
# 1053                                      longer,autom     48
# 513                                       brt,smaurizi     47
# 1423                                       smaurizi,We     47
# 1288                          putin,cambridgeanalytica     47
# 1522                                       trump,putin     47
# 570                            cambridgeanalytica,last     47
# 1020                                       last,friday     47
# 770                                   exclus,interview     47
# 864                               founder,julianassang     47
# 1635                                  wikileak,founder     47
# 582           cbse,exam\n\xe2\xa4\xb5\xef\xb8\x8fmoney     25
# 561    cambridg,analytica\n\xe2\xa4\xb5\xef\xb8\x8fpap     25
# 768           exam\n\xe2\xa4\xb5\xef\xb8\x8fmoney,leak     25
# 696   demonetisation\n\xe2\xa4\xb5\xef\xb8\x8ftax,leak     25
# 268        analytica\n\xe2\xa4\xb5\xef\xb8\x8fpap,leak     25
# ...                                                ...    ...
# 602                   co\xe2\x80\xa6,s//tco/g0ofvvpogj      1
# 601                                  client\namit,shah      1
# 600                clien\xe2\x80\xa6,s//tco/yqdzfzvc7o      1
# 597                                  claim,predecessor      1
# 596                                     claim,cambridg      1
# 595                                        circul,anon      1
# 594                             cineversitytv,facebook      1
# 616                                         confus,thi      1
# 618                                        congress,In      1
# 649                                          damag,due      1
# 635                                         counti,sue      1
# 648                                   dailybrief,\n\n1      1
# 647                                         daili,tech      1
# 645                                  cyberattack,escan      1
# 643                                   current,cambridg      1
# 641                                         culpa,tour      1
# 640                                    crisi,analytica      1
# 637                                  cowdung,analytica      1
# 636                                       countri,name      1
# 634                       counterattack,on\xe2\x80\xa6      1
# 620                                        congress,wa      1
# 633                                           could,Be      1
# 631                              cooki,jar\xe2\x80\xa6      1
# 628                                          cook,argu      1
# 627                                   controversi,data      1
# 626                                         contact,us      1
# 624                consult\xe2\x80\xa6,s//tco/snx4r7hk      1
# 623                                     consolid,power      1
# 621                               congression,committe      1
# 1664                   |\xe2\x80\xa6,s//tco/qvxzwu89so      1
#
# [1665 rows x 2 columns]

# %%
i=0

# %%
# only to be run if we need CoOccurence
isForCoOccurence = True

# %%
#targetFileName = "coOccNYT1DAY.js"
#targetFileName = "twitter1DAY.js"
targetFileName = "coOccTwitter1DAY.js"
f= open(targetFileName,"w+",encoding="utf-8")

# %%
strText = "var words = ["+"\n"
f.write(strText)
for index,row in sortedData.iterrows():
    i = i+1
    if i==nrows:
        eachRowVal = "\t"+"{text: '"+row['word']+"', size: "+str(row['count'])+"}"+"\n"
    else:
        eachRowVal = "\t"+"{text: '"+row['word']+"', size: "+str(row['count'])+"},"+"\n"
    f.write(eachRowVal)
endText = "];"
f.write(endText)
f.close()

# %%
# only to be run if we need CoOccurence!
strText = "var words = ["+"\n"
f.write(strText)
for index,row in sortedData.iterrows():
    i = i+1
    if i==10:
        eachRowVal = "\t"+"{text: '"+row['word']+"', size: "+str(row['count'])+"}"+"\n"
    else:
        eachRowVal = "\t"+"{text: '"+row['word']+"', size: "+str(row['count'])+"},"+"\n"
    f.write(eachRowVal)
    if i==10:
        break
endText = "];"
f.write(endText)
f.close()
