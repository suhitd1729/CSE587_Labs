# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
f = open("part-00000_CA.txt")
#print(f.read())
tableData = pd.read_table("part-00000_CA.txt", sep = "\t")
tableData.columns = ['word','count']
print(tableData)
# Out:
#              word  count
# 0              15      2
# 1            1994      1
# 2              20      1
# 3            2003      1
# 4            2011      1
# 5            2013      6
# 6        20132014      1
# 7            2014     10
# 8            2015      1
# 9            2016      8
# 10           2017      1
# 11        2017the      2
# 12      2017those      1
# 13           2018      1
# 14            230      1
# 15            250      1
# 16         270000      1
# 17              4     15
# 18    47000person      1
# 19       4announc      1
# 20             4s      2
# 21             50      9
# 22          50000      1
# 23              6      1
# 24              7      1
# 25              8      1
# 26              A      4
# 27             An      1
# 28             As      1
# 29             At      1
# ...           ...    ...
# 1308  whistleblow      1
# 1309        whole      1
# 1310       wholli      2
# 1311        whose      2
# 1312   widespread      1
# ...

# %%
sortedData = tableData.sort_values('count',ascending= False)
sortedData.head(10)
# Out:
#            word  count
# 338        data     83
# 216    cambridg     82
# 41           Mr     81
# 1015       said     79
# 104   analytica     67
# 468    facebook     63
# 1283         wa     52
# 287     compani     52
# 794         nix     37
# 1317       work     31

# %%
array = {}
for a, x in tableData.values:
    array[a] = x

wordcloud = WordCloud(background_color='yellow', width=2000,
                          height=2000)
wordcloud.generate_from_frequencies(frequencies = array)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
